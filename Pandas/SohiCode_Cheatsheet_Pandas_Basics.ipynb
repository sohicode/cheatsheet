# %% [markdown]
# **SohiCode Cheatsheet (edit 2022.10.14.)**
# <br> https://github.com/sohicode/cheatsheet/

# %% [markdown]
# # Pandas Basics

# %% [markdown]
# ## 데이터 구조

# %% [markdown]
# ### 판다스 라이브러리 활용

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 시리즈, 데이터프레임

# %%
s = pd.Series(['apple', 'banana', 'cherry'],
              index=['a', 'b', 'c'])

# %%
s
# Out:
# a     apple
# b    banana
# c    cherry
# dtype: object

# %%
pd.DataFrame([['rex', 11, 'climbing', 'apple'],
              ['dino', 9, 'drawing', 'korean pear'],
              ['mew', 13, 'traveling', 'blueberry']],
              index = [1, 2, 3],
              columns = ['name', 'age', 'hobby', 'fruit'])
# Out:
#    name  age      hobby        fruit
# 1   rex   11   climbing        apple
# 2  dino    9    drawing  korean pear
# 3   mew   13  traveling    blueberry

# %%
df = pd.DataFrame([['rex', 11, 140, 35],
                   ['dino', 9, 125, 30], ['mew', 13, 145, 40],
                   ['pengha', 8, 115, 20], ['kiki', 8, 130, 35]],
                  index = ['411', '211', '611', '111', '112'],
                  columns = ['name', 'age', 'height', 'weight'])

# %%
df
# Out:
#        name  age  height  weight
# 411     rex   11     140      35
# 211    dino    9     125      30
# 611     mew   13     145      40
# 111  pengha    8     115      20
# 112    kiki    8     130      35

# %% [markdown]
# ### 파일

# %%
#df = pd.read_csv('file.csv')
#df = pd.read_excel('file.xlsx', 'Sheet1')

# %%
df.to_csv('result_file.csv')
#df.to_excel('result_file.xlsx')

# %% [markdown]
# ## 데이터 확인

# %% [markdown]
# ### 데이터 정보 확인

# %%
df.shape
# Out:
# (5, 4)

# %%
df.head()
# Out:
#        name  age  height  weight
# 411     rex   11     140      35
# 211    dino    9     125      30
# 611     mew   13     145      40
# 111  pengha    8     115      20
# 112    kiki    8     130      35

# %%
df.tail(3)
# Out:
#        name  age  height  weight
# 611     mew   13     145      40
# 111  pengha    8     115      20
# 112    kiki    8     130      35

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 411 to 112
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5 non-null      object
#  1   age     5 non-null      int64
#  2   height  5 non-null      int64
#  3   weight  5 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 200.0+ bytes

# %%
df.describe()
# Out:
#              age      height     weight
# count   5.000000    5.000000   5.000000
# mean    9.800000  131.000000  32.000000
# std     2.167948   11.937336   7.582875
# min     8.000000  115.000000  20.000000
# 25%     8.000000  125.000000  30.000000
# 50%     9.000000  130.000000  35.000000
# 75%    11.000000  140.000000  35.000000
# max    13.000000  145.000000  40.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 411 to 112
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5 non-null      object
#  1   age     5 non-null      int64
#  2   height  5 non-null      int64
#  3   weight  5 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 200.0+ bytes

# %%
df.describe()
# Out:
#              age      height     weight
# count   5.000000    5.000000   5.000000
# mean    9.800000  131.000000  32.000000
# std     2.167948   11.937336   7.582875
# min     8.000000  115.000000  20.000000
# 25%     8.000000  125.000000  30.000000
# 50%     9.000000  130.000000  35.000000
# 75%    11.000000  140.000000  35.000000
# max    13.000000  145.000000  40.000000

# %%
df.index
# Out:
# Index(['411', '211', '611', '111', '112'], dtype='object')

# %%
df.columns
# Out:
# Index(['name', 'age', 'height', 'weight'], dtype='object')

# %%
df.values
# Out:
# array([['rex', 11, 140, 35],
#        ['dino', 9, 125, 30],
#        ['mew', 13, 145, 40],
#        ['pengha', 8, 115, 20],
#        ['kiki', 8, 130, 35]], dtype=object)

# %%
df.dtypes
# Out:
# name      object
# age        int64
# height     int64
# weight     int64
# dtype: object

# %%
df.nunique()
# Out:
# name      5
# age       4
# height    5
# weight    4
# dtype: int64

# %% [markdown]
# ### 정렬

# %%
df
# Out:
#        name  age  height  weight
# 411     rex   11     140      35
# 211    dino    9     125      30
# 611     mew   13     145      40
# 111  pengha    8     115      20
# 112    kiki    8     130      35

# %%
df.sort_index()
# Out:
#        name  age  height  weight
# 111  pengha    8     115      20
# 112    kiki    8     130      35
# 211    dino    9     125      30
# 411     rex   11     140      35
# 611     mew   13     145      40

# %%
df.sort_values(by='height')
# Out:
#        name  age  height  weight
# 111  pengha    8     115      20
# 211    dino    9     125      30
# 112    kiki    8     130      35
# 411     rex   11     140      35
# 611     mew   13     145      40

# %%
df.sort_values('weight')
# Out:
#        name  age  height  weight
# 111  pengha    8     115      20
# 211    dino    9     125      30
# 411     rex   11     140      35
# 112    kiki    8     130      35
# 611     mew   13     145      40

# %%
df.sort_values('weight', ascending=False)
# Out:
#        name  age  height  weight
# 611     mew   13     145      40
# 411     rex   11     140      35
# 112    kiki    8     130      35
# 211    dino    9     125      30
# 111  pengha    8     115      20

# %% [markdown]
# ### 순위

# %%
df
# Out:
#        name  age  height  weight
# 411     rex   11     140      35
# 211    dino    9     125      30
# 611     mew   13     145      40
# 111  pengha    8     115      20
# 112    kiki    8     130      35

# %%
df.rank()
# Out:
#      name  age  height  weight
# 411   5.0  4.0     4.0     3.5
# 211   1.0  3.0     2.0     2.0
# 611   3.0  5.0     5.0     5.0
# 111   4.0  1.5     1.0     1.0
# 112   2.0  1.5     3.0     3.5

# %%
df.rank(method='min')
# Out:
#      name  age  height  weight
# 411   5.0  4.0     4.0     3.0
# 211   1.0  3.0     2.0     2.0
# 611   3.0  5.0     5.0     5.0
# 111   4.0  1.0     1.0     1.0
# 112   2.0  1.0     3.0     3.0

# %%
df[df['height'].rank()==1.0]
# Out:
#        name  age  height  weight
# 111  pengha    8     115      20

# %% [markdown]
# ### 그래프

# %%
df['age'].plot.hist()

# %%
df.plot.scatter(x=2, y=3)

# %% [markdown]
# ## 데이터 선택

# %% [markdown]
# ### 인덱스로 선택하기

# %%
df.iloc[0]
# Out:
# name      rex
# age        11
# height    140
# weight     35
# Name: 411, dtype: object

# %%
df.iloc[1]
# Out:
# name      dino
# age          9
# height     125
# weight      30
# Name: 211, dtype: object

# %%
df.iloc[-1]
# Out:
# name      kiki
# age          8
# height     130
# weight      35
# Name: 112, dtype: object

# %%
df.iloc[[0, 2, 4]]
# Out:
#      name  age  height  weight
# 411   rex   11     140      35
# 611   mew   13     145      40
# 112  kiki    8     130      35

# %%
df.iloc[0:2]
# Out:
#      name  age  height  weight
# 411   rex   11     140      35
# 211  dino    9     125      30

# %%
df.iloc[:, 0]
# Out:
# 411       rex
# 211      dino
# 611       mew
# 111    pengha
# 112      kiki
# Name: name, dtype: object

# %%
df.iloc[:, 1]
# Out:
# 411    11
# 211     9
# 611    13
# 111     8
# 112     8
# Name: age, dtype: int64

# %%
df.iloc[:, -1]
# Out:
# 411    35
# 211    30
# 611    40
# 111    20
# 112    35
# Name: weight, dtype: int64

# %%
df.iloc[0:3, 0:2]
# Out:
#      name  age
# 411   rex   11
# 211  dino    9
# 611   mew   13

# %% [markdown]
# ### 레이블로 선택하기

# %%
df.loc['611']
# Out:
# name      mew
# age        13
# height    145
# weight     40
# Name: 611, dtype: object

# %%
df.loc['411':'611']
# Out:
#      name  age  height  weight
# 411   rex   11     140      35
# 211  dino    9     125      30
# 611   mew   13     145      40

# %%
df.loc[:, 'name']
# Out:
# 411       rex
# 211      dino
# 611       mew
# 111    pengha
# 112      kiki
# Name: name, dtype: object

# %%
df.loc[:, ['name', 'age']]
# Out:
#        name  age
# 411     rex   11
# 211    dino    9
# 611     mew   13
# 111  pengha    8
# 112    kiki    8

# %% [markdown]
# ### 인덱스, 레이블 비교

# %%
comp_df = pd.DataFrame([['rex', 11, 'climbing', 'apple'],
              ['dino', 9, 'drawing', 'korean pear'],
              ['mew', 13, 'traveling', 'blueberry']],
              index = [1, 2, 3],
              columns = ['name', 'age', 'hobby', 'fruit'])

# %%
comp_df.iloc[1]
# Out:
# name            dino
# age                9
# hobby        drawing
# fruit    korean pear
# Name: 2, dtype: object

# %%
comp_df.loc[1]
# Out:
# name          rex
# age            11
# hobby    climbing
# fruit       apple
# Name: 1, dtype: object

# %% [markdown]
# ### 조건으로 선택하기

# %%
df['name']
# Out:
# 411       rex
# 211      dino
# 611       mew
# 111    pengha
# 112      kiki
# Name: name, dtype: object

# %%
df.name
# Out:
# 411       rex
# 211      dino
# 611       mew
# 111    pengha
# 112      kiki
# Name: name, dtype: object

# %%
df[df.age > 10]
# Out:
#     name  age  height  weight
# 411  rex   11     140      35
# 611  mew   13     145      40

# %%
df.loc[df['age'] > 10, ['name', 'age']]
# Out:
#     name  age
# 411  rex   11
# 611  mew   13

# %%
df[['name', 'age']]
# Out:
#        name  age
# 411     rex   11
# 211    dino    9
# 611     mew   13
# 111  pengha    8
# 112    kiki    8

# %%
df[df['height'] < 140]
# Out:
#        name  age  height  weight
# 211    dino    9     125      30
# 111  pengha    8     115      20
# 112    kiki    8     130      35

# %%
df[(df['height'] > 120) & (df['height'] < 140) ]
# Out:
#      name  age  height  weight
# 211  dino    9     125      30
# 112  kiki    8     130      35

# %%
df[df['age'] == 8]
# Out:
#        name  age  height  weight
# 111  pengha    8     115      20
# 112    kiki    8     130      35

# %%
df[~(df['age'] == 8)]
# Out:
#      name  age  height  weight
# 411   rex   11     140      35
# 211  dino    9     125      30
# 611   mew   13     145      40

# %% [markdown]
# ## 데이터 연산

# %% [markdown]
# ### 벡터화 연산

# %%
df.age + 1
# Out:
# 411    12
# 211    10
# 611    14
# 111     9
# 112     9
# Name: age, dtype: int64

# %%
df.weight * 2
# Out:
# 411    70
# 211    60
# 611    80
# 111    40
# 112    70
# Name: weight, dtype: int64

# %%
df.weight / ((df.height / 100) ** 2)
# Out:
# 411    17.857143
# 211    19.200000
# 611    19.024970
# 111    15.122873
# 112    20.710059
# dtype: float64

# %%
df['bmi'] = df.weight / ((df.height / 100) ** 2)

# %%
df
# Out:
#        name  age  height  weight        bmi
# 411     rex   11     140      35  17.857143
# 211    dino    9     125      30  19.200000
# 611     mew   13     145      40  19.024970
# 111  pengha    8     115      20  15.122873
# 112    kiki    8     130      35  20.710059

# %%
df.bmi = df.bmi.round(2)

# %%
df
# Out:
#        name  age  height  weight    bmi
# 411     rex   11     140      35  17.86
# 211    dino    9     125      30  19.20
# 611     mew   13     145      40  19.02
# 111  pengha    8     115      20  15.12
# 112    kiki    8     130      35  20.71

# %% [markdown]
# ### 집계 연산

# %%
df.sum()
# Out:
# name      rexdinomewpenghakiki
# age                         49
# height                     655
# weight                     160
# bmi                      91.91
# dtype: object

# %%
df.count()
# Out:
# name      5
# age       5
# height    5
# weight    5
# bmi       5
# dtype: int64

# %%
df.min()
# Out:
# name       dino
# age           8
# height      115
# weight       20
# bmi       15.12
# dtype: object

# %%
df.max()
# Out:
# name        rex
# age          13
# height      145
# weight       40
# bmi       20.71
# dtype: object

# %%
df.height.min()
# Out:
# 115

# %%
df.height.idxmin()
# Out:
# '111'

# %%
df.height.max()
# Out:
# 145

# %%
df.weight.idxmax()
# Out:
# '611'

# %%
df.height.mean()
# Out:
# 131.0

# %%
df.height.median()
# Out:
# 130.0

# %%
df.height.std()
# Out:
# 11.937336386313323

# %%
df.height.var()
# Out:
# 142.5

# %%
df.value_counts()
# Out:
# name    age  height  weight  bmi
# dino    9    125     30      19.20    1
# kiki    8    130     35      20.71    1
# mew     13   145     40      19.02    1
# pengha  8    115     20      15.12    1
# rex     11   140     35      17.86    1
# dtype: int64

# %%
df['age'].value_counts()
# Out:
# 8     2
# 11    1
# 9     1
# 13    1
# Name: age, dtype: int64

# %% [markdown]
# ## 데이터 전처리

# %%
df = pd.DataFrame([['rex', 11, np.NaN, 35],
                   ['dino', 9, 125, 30], ['mew', 13, 145, np.NaN],
                   ['pengha', np.NaN, 115, 20], ['kiki', 8, 130, 35]],
                  index = ['411', '211', '611', '111', '112'],
                  columns = ['name', 'age', 'height', 'weight'])

# %%
df.isna()
# Out:
#       name    age  height  weight
# 411  False  False    True   False
# 211  False  False   False   False
# 611  False  False   False    True
# 111  False   True   False   False
# 112  False  False   False   False

# %%
df.isnull()
# Out:
#       name    age  height  weight
# 411  False  False    True   False
# 211  False  False   False   False
# 611  False  False   False    True
# 111  False   True   False   False
# 112  False  False   False   False

# %%
df[df.weight.isnull()]
# Out:
#     name   age  height  weight
# 611  mew  13.0   145.0     NaN

# %%
df.notna()
# Out:
#      name    age  height  weight
# 411  True   True   False    True
# 211  True   True    True    True
# 611  True   True    True   False
# 111  True  False    True    True
# 112  True   True    True    True

# %%
df.notnull()
# Out:
#      name    age  height  weight
# 411  True   True   False    True
# 211  True   True    True    True
# 611  True   True    True   False
# 111  True  False    True    True
# 112  True   True    True    True

# %%
df.dropna()
# Out:
#      name  age  height  weight
# 211  dino  9.0   125.0    30.0
# 112  kiki  8.0   130.0    35.0

# %%
df.weight.dropna()
# Out:
# 411    35.0
# 211    30.0
# 111    20.0
# 112    35.0
# Name: weight, dtype: float64

# %%
df.dropna(subset=['weight'])
# Out:
#        name   age  height  weight
# 411     rex  11.0     NaN    35.0
# 211    dino   9.0   125.0    30.0
# 111  pengha   NaN   115.0    20.0
# 112    kiki   8.0   130.0    35.0

# %%
df.dropna(subset=['weight', 'height'])
# Out:
#        name  age  height  weight
# 211    dino  9.0   125.0    30.0
# 111  pengha  NaN   115.0    20.0
# 112    kiki  8.0   130.0    35.0

# %%
df.fillna(0)
# Out:
#        name   age  height  weight
# 411     rex  11.0     0.0    35.0
# 211    dino   9.0   125.0    30.0
# 611     mew  13.0   145.0     0.0
# 111  pengha   0.0   115.0    20.0
# 112    kiki   8.0   130.0    35.0

# %%
df['age'].fillna(df['age'].mean().astype(int))
# Out:
# 411    11.0
# 211     9.0
# 611    13.0
# 111    10.0
# 112     8.0
# Name: age, dtype: float64

# %%
df.drop_duplicates()
# Out:
#        name   age  height  weight
# 411     rex  11.0     NaN    35.0
# 211    dino   9.0   125.0    30.0
# 611     mew  13.0   145.0     NaN
# 111  pengha   NaN   115.0    20.0
# 112    kiki   8.0   130.0    35.0

# %%
df = pd.DataFrame([['rex', 11, np.NaN, 35],
                   ['rex', 11, np.NaN, 35],
                   ['rex', 11, np.NaN, 35],
                   ['dino', 9, 125, 30], ['mew', 13, 145, np.NaN],
                   ['pengha', np.NaN, 115, 20], ['kiki', 8, 130, 35]],
                  index = ['411', '000', 'xxx', '211', '611', '111', '112'],
                  columns = ['name', 'age', 'height', 'weight'])

# %%
df
# Out:
#        name   age  height  weight
# 411     rex  11.0     NaN    35.0
# 000     rex  11.0     NaN    35.0
# xxx     rex  11.0     NaN    35.0
# 211    dino   9.0   125.0    30.0
# 611     mew  13.0   145.0     NaN
# 111  pengha   NaN   115.0    20.0
# 112    kiki   8.0   130.0    35.0

# %%
df.drop_duplicates()
# Out:
#        name   age  height  weight
# 411     rex  11.0     NaN    35.0
# 211    dino   9.0   125.0    30.0
# 611     mew  13.0   145.0     NaN
# 111  pengha   NaN   115.0    20.0
# 112    kiki   8.0   130.0    35.0
